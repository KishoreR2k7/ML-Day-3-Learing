# %%
import numpy as np
import pandas as pd
df=pd.read_csv('lasso_sparse_150 (1).csv')
df.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0  0.256659 -1.714486 -0.713819  0.771874 -0.279677 -0.512061  1.400882
# 1  0.098002  2.337845 -0.378039  0.324089 -0.798806 -0.351525  0.248934
# 2 -0.521539 -0.943954  1.301158  0.633422  0.604993  1.247211  2.812649
# 3  0.726098 -0.931073 -0.999145  0.036805  0.173007 -1.856312 -0.180307
# 4  0.092679 -0.768356  0.085993 -0.794044 -1.099658  0.234298  0.150922
#
#          x8        x9       x10  ...       x22       x23       x24       x25  \
# 0 -1.047287 -0.798153  0.211386  ...  0.044217 -0.809126  0.067671 -0.028018
# 1  0.846304  0.319095  1.259115  ...  0.731492 -0.846744 -1.075572  0.224297
# 2 -1.709226 -0.738377 -0.616175  ...  0.234431 -1.862485 -1.002376 -1.740503
# 3  0.014072 -0.215149 -0.813390  ...  0.979585  1.291686  1.778321 -0.866416
# 4  0.579282  2.185864  0.277290  ... -0.805994 -1.393672  0.942594  0.492297
#
#         x26       x27       x28       x29       x30          y
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LassoCV
from sklearn.metrics import mean_squared_error,r2_score
x=df[['x1','x2']]
y=df['y']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LassoCV(cv=5,random_state=42)
model.fit(x_train,y_train)  # fit the model in lasso
print(f'Best alpha:{model.alpha_}\n')
y_pred=model.predict(x_test)
coefficients=pd.Series(model.coef_, index=x.columns)  # Identify which features Lasso selects (non-zero coefficientts)
print('non-zero coefficients:')
print(f'{coefficients[coefficients != 0]}\n')
print(f'R^2:{r2_score(y_test,y_pred)}\n')
print(f'RMSE:{np.sqrt(mean_squared_error(y_test,y_pred))}')
# Out:
# Best alpha:0.021817484513096536
#
# non-zero coefficients:
# x1   -0.971723
# x2    3.070013
# dtype: float64
#
# R^2:0.5154391265395539
#
# RMSE:4.240345876428519
