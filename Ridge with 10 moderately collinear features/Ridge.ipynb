# %%
import numpy as np
import pandas as pd
df=pd.read_csv('ridge_10feat_150.csv')
df.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0 -0.131138  0.348776  1.951013 -0.053199 -0.073963  1.725846  0.167062
# 1  2.076981  0.069381  0.160191  2.097491 -0.006123 -0.560142  2.258816
# 2  1.076240 -0.845661  0.333070  1.046752 -0.400901  0.094244 -0.027797
# 3 -0.025863  0.313908 -0.833369  0.291792  0.645980 -0.846089  0.358571
# 4 -1.589567 -2.072983 -1.117384 -1.714009 -1.311955 -0.770627 -3.279960
#
#          x8        x9       x10         y
# 0  2.186529 -1.363724 -0.039706 -1.313471
# 1  0.104651  1.612349  0.442455  8.190274
# 2 -0.247561  0.660785 -0.304427  4.060418
# 3 -0.453403  0.404791 -0.409649 -0.326414
# 4 -3.232714 -0.489556  0.092354 -2.902295

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import RidgeCV
from sklearn.metrics import r2_score, mean_squared_error
x=df[['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10']]
y=df['y']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=RidgeCV(alphas=np.logspace(-3,3,100),cv=5)
model.fit(x_train,y_train)  # fit the model in ridge
print(f'Best alpha:{model.alpha_}\n')
print(f'coefficients:{model.coef_}\n')
print(f'Intercept:{model.intercept_}\n')
y_pred=model.predict(x_test)
print(f'R^2:{r2_score(y_test,y_pred)}\n')
print(f'RMSE:{np.sqrt(mean_squared_error(y_test,y_pred))}\n')
# Out:
# Best alpha:0.9326033468832199
#
# coefficients:[ 2.19628041 -1.28418814  0.32137054  1.57736975 -0.20158655 -0.69677176
#  -0.14694893  0.01430321  0.06655033  0.05110447]
#
# Intercept:-0.07514098356735302
#
# R^2:0.9883646787447763
#
# RMSE:0.6012015016417609
